# %% [markdown]
# # Python Assignment - Working With Events
#
# In this question, you are given 4 text files.
# These files contain timestamps, which correspond to the times of some 'events'.
#
# Your first task is to find out how many events are present in each file.
#
# Consider only those events which have a positive value for timestamp

# %%
#your code here
#code to convert txt file to csv 
import pandas as pd

dataframe1=pd.read_csv('event_Q1.txt')

dataframe1.to_csv('event_Q1.csv',index=None)
#the above thing was done to the remaining 3 files as well to convert them to csv files.

#now to read the events in each file
#1
import pandas as pd
result = pd.read_csv('event_Q1.csv')
print(result)
count=0
for column in result:
    if (float(column)>0 ):
        count=count + 1
print(count)
#answer was 6528

#2
import pandas as pd
result = pd.read_csv('event_Q2.csv')
print(result)
count=0
for column in result:
    if (float(column)>0 ):
        count=count + 1
print(count)
#answer wa 7800

#3
import pandas as pd
result = pd.read_csv('event_Q3.csv')
print(result)
count=0
for column in result:
    if (float(column)>0 ):
        count=count + 1
print(count)
#answer was 7858

#4
import pandas as pd
result = pd.read_csv('event_Q4.csv')
print(result)
count=0
for column in result:
    if (float(column)>0 ):
        count=count + 1
print(count)
#answer was 5193

# %% [markdown]
# After this, for each file, make a plot of events per second in that file.
# You dont have to find the average rate, instead for each second 0-1, 1-2, 2-3, .. 54-55, find the number of events in each second and plot it with respect to time.
#
# Plot these 4 separately, as well as in a single overlapping plot.
# Make sure to give proper titles, labels and legends.

# %%
#your code here
#for file 1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

result = pd.read_csv('event_Q1.csv')
count=0
y=np.empty(6528)
z=np.empty(6528)
for column in result:
    if (float(column)>0 ):
        x=int(float(column))
        y[count]=x
        count=count + 1 

for i in range(6528):
    z[i]=0
for i in range(55):
    z[i]=i

plt.ylabel("number of events")
plt.xlabel("time interval")
plt.title("events vs time bar graph for file 1")
plt.bar(y,z,color='green')
plt.show()

#for file 2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

result = pd.read_csv('event_Q2.csv')
count=0
y=np.empty(7800)
z=np.empty(7800)
for column in result:
    if (float(column)>0 ):
        x=int(float(column))
        y[count]=x
        count=count + 1 

for i in range(7800):
    z[i]=0
for i in range(55):
    z[i]=i

plt.ylabel("number of events")
plt.xlabel("time interval")
plt.title("events vs time bar graph for file 2")
plt.bar(y,z,color='green')
plt.show()

#for file 3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

result = pd.read_csv('event_Q3.csv')
count=0
y=np.empty(7858)
z=np.empty(7858)
for column in result:
    if (float(column)>0 ):
        x=int(float(column))
        y[count]=x
        count=count + 1 

for i in range(7858):
    z[i]=0
for i in range(55):
    z[i]=i

plt.ylabel("number of events")
plt.xlabel("time interval")
plt.title("events vs time bar graph for file 3")
plt.bar(y,z,color='green')
plt.show()

#for file 4
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

result = pd.read_csv('event_Q4.csv')
count=0
y=np.empty(5193)
z=np.empty(5193)
for column in result:
    if (float(column)>0 ):
        x=int(float(column))
        y[count]=x
        count=count + 1 

for i in range(5193):
    z[i]=0
for i in range(55):
    z[i]=i

plt.ylabel("number of events")
plt.xlabel("time interval")
plt.title("events vs time bar graph for file 4")
plt.bar(y,z,color='green')
plt.show()

#for all 4 files combined
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

result1 = pd.read_csv('event_Q1.csv')
result2 = pd.read_csv('event_Q2.csv')
result3 = pd.read_csv('event_Q3.csv')
result4 = pd.read_csv('event_Q4.csv')

count1=0
count2=0
count3=0
count4=0

y1=np.empty(6528)
z1=np.empty(6528)

for column in result1:
    if (float(column)>0 ):
        x=int(float(column))
        y1[count1]=x
        count1=count1 + 1 

for i in range(6528):
    z1[i]=0
for i in range(55):
    z1[i]=i

y2=np.empty(7800)
z2=np.empty(7800)

for column in result2:
    if (float(column)>0 ):
        x=int(float(column))
        y2[count2]=x
        count2=count2 + 1 

for i in range(6528):
    z2[i]=0
for i in range(55):
    z2[i]=i

y3=np.empty(7858)
z3=np.empty(7858)

for column in result3:
    if (float(column)>0 ):
        x=int(float(column))
        y3[count3]=x
        count3=count3 + 1 

for i in range(7858):
    z3[i]=0
for i in range(55):
    z3[i]=i

y4=np.empty(5193)
z4=np.empty(5193)

for column in result4:
    if (float(column)>0 ):
        x=int(float(column))
        y4[count4]=x
        count4=count4 + 1 

for i in range(5193):
    z4[i]=0
for i in range(55):
    z4[i]=i

plt.ylabel("number of events")
plt.xlabel("time interval")
plt.title("events vs time bar graph")
plt.bar(y1,z1,color='green')
plt.bar(y2,z2,color='brown')
plt.bar(y3,z3,color='blue')
plt.bar(y4,z4,color='red')
plt.legend(["event1","event2","event3","event4"],loc ="best")
plt.show()

# %% [markdown]
# Give your insights on what you observe in the various plots. Regarding frequency of events in various files as well as the total duration each file is covering.

# %%
#your code here
#the frequency of events happening in the 10s to 30s time interval is much larger. moreover there are some
#events happening in almost every time partition in this interval

#in file 1 
import pandas as pd
result = pd.read_csv('event_Q1.csv')
sum_time=0
for column in result:
    if(float(column)>0):
        sum_time = sum_time + float(column)
print(sum_time)
#total time for events in file 1 is 160304.6500923675

#in file 2
import pandas as pd
result = pd.read_csv('event_Q2.csv')
sum_time=0
for column in result:
    if(float(column)>0):
        sum_time = sum_time + float(column)
print(sum_time)
#total time for events in file 2 is 213340.93628755197

#in file 3
import pandas as pd
result = pd.read_csv('event_Q3.csv')
sum_time=0
for column in result:
    if(float(column)>0):
        sum_time = sum_time + float(column)
print(sum_time)
#total time for events in file 3 is 205047.43449312882

#in file 4
import pandas as pd
result = pd.read_csv('event_Q4.csv')
sum_time=0
for column in result:
    if(float(column)>0):
        sum_time = sum_time + float(column)
print(sum_time)
#total time for events in file 4 is 109501.40287649773

# %% [markdown]
# Now for the final part of this question. We can see that the event frequency varies with time. Count how many bins are there, where atleast 2 of the files have more than 140 events in that bin, simultaneously.

# %%
#your code here

# %% [markdown]
# ## Bonus
#
# Let us do this more generally Generate a table with the threshold along one axis and the number of files along the other axis. Fill the table with counts of bins where atleast num_files have more than threshold events in that bin. In the previous part, num_files was 2 and num_bins was 140. Do this for num_files in [1,2,3,4]. num_bins in [130,135,140,145,150,155,160]. Print the table.

# %%
#your code here
